# %% [markdown]
# # OpenCV Setup

# %%
! pip install opencv-python
! pip install matplotlib

# %% [markdown]
# # Intro

# %% [markdown]
# x-- Only for Linux KDE --x

# %%
import os
os.environ['QT_QPA_PLATFORM'] = 'xcb'

# %% [markdown]
# ## Import OpenCV Library

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def print_cv(image , title="Image"):
    # Display the image using Matplotlib
    plt.title(title)
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.axis('off')  # Turn off axis labels
    plt.show()

# %%
def show_cv(image , title="Image" , end_time=0 ):
    # Display the image using matplotlib
    cv2.imshow(title, image)
    cv2.waitKey(end_time)
    cv2.destroyAllWindows()

# %%
def read_cv(image_location , image_mode = -1):
    return cv2.imread(image_location , image_mode)

# %%
def write_cv(image_location:str , image):
    return cv2.imwrite(image_location , image)

# %%
def resize_cv(image , width , height):
    return cv2.resize(image , (width , height))

# %%
def rotate_cv(image , rotation:int = 0):
    rotation = rotation % 4 - 1
    if rotation == -1:
        return image
    return cv2.rotate(image , rotation)

# %% [markdown]
# ## Load a Image from folder "assets"

# %%
img = cv2.imread("assets/image.jpg" )
## Show the image   
cv2.imshow("Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# With user define function
img = cv2.imread("assets/image.jpg" )
show_cv(img)

# %% [markdown]
# Use matplotlib to show the image

# %%
# Load an image from your file system
image = cv2.imread('assets/image.jpg')

# Display the image using matplotlib
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')  # Turn off axis labels
plt.show()

# %% [markdown]
# ## Resize Image

# %%
img = cv2.imread("assets/image.jpg")
img = cv2.resize(img, (500, 600))
print_cv(img)

# %%
img = read_cv("assets/image.jpg")
print_cv(img)

# %%
from OpenCV_Simple.OpenCV_Simple import *

img = read_cv("assets/image.jpg" , "cv2.IMREAD_GRAYSCALE")
# img = rotate_cv(img , 90)
# img = cv2.rotate(img)
img = rotate_cv(img , -1)
# print_cv( resize_cv(img , 500 , 700) )
print_cv(img)

# %%
write_cv("assets/image_new.jpg" , img)
# Out:
# True
